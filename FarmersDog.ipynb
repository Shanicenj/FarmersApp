# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('https://s3.amazonaws.com/interview.thefarmersdog.com/DA20b/general_store_sample_data.csv', header = 0)

# %%
data
# Out:
#        product_group country  year        revenue
# 0         automobile      BR  2012  206937.326525
# 1         automobile      BR  2013  199547.386832
# 2         automobile      BR  2014  192515.411446
# 3         automobile      CA  2012  197552.325143
# 4         automobile      CA  2013  197965.016752
# ..               ...     ...   ...            ...
# 175  office supplies      ZA  2013  208051.353956
# 176  office supplies      ZA  2014  214117.720539
# 177  office supplies      ZH  2012  189211.781700
# 178  office supplies      ZH  2013  191593.130571
# 179  office supplies      ZH  2014  199955.850031
#
# [180 rows x 4 columns]

# %%
for col, values in data.iteritems():

    num_uniques = values.nunique()
    print ('{name}: {num_unique}'.format(name=col, num_unique=num_uniques))
    print (values.unique())
    print ('\n')
# Out:
# product_group: 6
# ['automobile' 'clothing' 'electronics' 'furniture' 'groceries'
#  'office supplies']
#
#
# country: 10
# ['BR' 'CA' 'CL' 'DE' 'ES' 'FR' 'GB' 'US' 'ZA' 'ZH']
#
#
# year: 3
# [2012 2013 2014]
#
#
# revenue: 180
# [206937.32652506 199547.38683181 192515.41144649 197552.32514272
#  197965.01675158 200263.55366564 203331.92724441 197857.02413439
#  206759.71298895 209905.22137357 200636.59514625 197499.01597094
#  200855.76970515 193957.39270146 195584.84501577 190734.68147838
#  197659.86185767 197206.02948522 204522.47559446 189077.61012623
#  196398.90956154 201789.70138624 198326.24113047 204902.7911174
#  188605.51830608 208943.13036826 194365.93722725 186944.52710262
#  192123.61368613 201206.25670936   2512.66862716   1705.94395652
#    2816.58788901   2082.22356109   2916.56486909   2580.24603122
#    1224.51513085   2182.46847257   1495.5133718    2085.35649145
#    1757.50734169   2910.09478286   1081.70537951   3112.4395557
# ...

# %%
NEWDF = data[(data.country == 'US') | (data.country == 'ES') | (data.country == 'FR')]
NEWDF
# Out:
#        product_group country  year        revenue
# 12        automobile      ES  2012  200855.769705
# 13        automobile      ES  2013  193957.392701
# 14        automobile      ES  2014  195584.845016
# 15        automobile      FR  2012  190734.681478
# 16        automobile      FR  2013  197659.861858
# 17        automobile      FR  2014  197206.029485
# 21        automobile      US  2012  201789.701386
# 22        automobile      US  2013  198326.241130
# 23        automobile      US  2014  204902.791117
# 42          clothing      ES  2012    1081.705380
# 43          clothing      ES  2013    3112.439556
# 44          clothing      ES  2014     912.813255
# 45          clothing      FR  2012    1873.328854
# 46          clothing      FR  2013    3346.136628
# 47          clothing      FR  2014    1241.063181
# 51          clothing      US  2012    1865.099225
# 52          clothing      US  2013    1926.057675
# 53          clothing      US  2014    1491.881474
# ...

# %%
for col, values in NEWDF.iteritems():

    num_uniques = values.nunique()
    print ('{name}: {num_unique}'.format(name=col, num_unique=num_uniques))
    print (values.unique())
    print ('\n')
# Out:
# product_group: 6
# ['automobile' 'clothing' 'electronics' 'furniture' 'groceries'
#  'office supplies']
#
#
# country: 3
# ['ES' 'FR' 'US']
#
#
# year: 3
# [2012 2013 2014]
#
#
# revenue: 54
# [200855.76970515 193957.39270146 195584.84501577 190734.68147838
#  197659.86185767 197206.02948522 201789.70138624 198326.24113047
#  204902.7911174    1081.70537951   3112.4395557     912.81325527
#    1873.32885418   3346.13662834   1241.06318077   1865.09922466
#    1926.05767456   1491.88147444  19505.46747675  20348.10266055
#   19643.28124503  20352.77235302  19615.28342904  19475.63671129
#   20175.30882352  19824.93155382  19250.15381874  19799.61815384
#   20932.97424473  19095.47777902  21392.75366463  19032.5859175
#   20349.47866843  19864.1973243   20146.53481655  19907.13508244
#  147368.00343702 203526.21141496 194360.71440775 238991.33667501
#  223017.38029132 189053.4343644  208650.10211935 167057.54445374
#  213302.74562163 206106.3299504  191076.73045739 204295.84303092
# ...

# %%
NEWDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 12 to 173
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_group  54 non-null     object
#  1   country        54 non-null     object
#  2   year           54 non-null     int64
#  3   revenue        54 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.6+ KB

# %%
AGG = NEWDF.groupby(['year']).agg({'revenue': ['median']})
AGG
# Out:
#             revenue
#              median
# year
# 2012   84380.378551
# 2013   93995.259349
# 2014  104701.456516

# %%
COUNTRYMEDIANS = NEWDF.groupby(['country', 'year']).agg({'revenue': ['median']})
COUNTRYMEDIANS
# Out:
#                     revenue
#                      median
# country year
# ES      2012   83583.810795
#         2013  106004.852351
#         2014  107001.997826
# FR      2012  106063.717572
#         2013  108637.572643
#         2014  104701.456516
# US      2012  110982.505105
#         2013   93602.039635
#         2014  109401.482167

# %%
AGG2 = NEWDF.groupby(['product_group', 'year']).agg({'revenue': ['median']})
AGG2
# Out:
#                             revenue
#                              median
# product_group   year
# automobile      2012  200855.769705
#                 2013  197659.861858
#                 2014  197206.029485
# clothing        2012    1865.099225
#                 2013    3112.439556
#                 2014    1241.063181
# electronics     2012   20175.308824
#                 2013   19824.931554
#                 2014   19475.636711
# furniture       2012   19864.197324
#                 2013   20146.534817
#                 2014   19907.135082
# groceries       2012  208650.102119
#                 2013  203526.211415
#                 2014  194360.714408
# office supplies 2012  206106.329950
#                 2013  207829.132649
#                 2014  204295.843031
